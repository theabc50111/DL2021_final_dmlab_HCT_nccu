# %%
from eda import EDA
from preprocessing import GetData
from pathlib import Path


get_data = GetData(Path('./dataset'))
obj_ticker = 'APA'
price_type = 'Adj Close'

price_df = get_data.get_price_data(price_type=price_type, ticker_list=[obj_ticker])

apa_eda = EDA(obj_ticker, price_type)
apa_eda.draw_ori_price(price_df)
print("-"*200)
apa_eda.test_stationarity(price_df)
print("-"*200)
apa_eda.seasonal_decompose(price_df,120)
print("-"*200)
# Out:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Results of dickey fuller test
# Test Statistics                  -1.417150
# p-value                           0.574027
# No. of lags used                  6.000000
# Number of observations used    2875.000000
# critical value (1%)              -3.432627
# critical value (5%)              -2.862546
# critical value (10%)             -2.567305
# dtype: float64
# *=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=*=
# APA's Adj Close is not stationary
# ...
